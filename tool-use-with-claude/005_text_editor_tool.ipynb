# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calcualte pi to the 5th digit.

    Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and then write tests for it.
#
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (also known as the Gregory-Leibniz series) which is a simple and elegant method:
# Now let's create a test file to verify our implementation:
# Perfect! I've created both files. Let me show you what was created:
# ## Summary
#
# I've successfully created:
#
# ### **`./main.py`** - Contains the pi calculation function
# - **`calculate_pi(digits=5)`**: Calculates pi to the specified number of decimal digits (default 5)
# - Uses **Machin's formula**: π/4 = 4·arctan(1/5) - arctan(1/239)
# - This formula converges much faster than simpler methods like the Leibniz series
# - Implements the arctan function using Taylor series expansion
# - Should accurately calculate pi to at least 5 decimal places (3.14159)
#
# ### **`./test.py`** - Comprehensive test suite
# Contains three test functions:
# 1. **`test_pi_5_digits()`**: Verifies pi is calculated correctly to 5 decimal places
# 2. **`test_pi_different_precisions()`**: Tests multiple precision levels (3, 5, 7, 10 digits)
# 3. **`test_pi_value_range()`**: Ensures the calculated value is within the expected range
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
#
# The implementation should output pi as approximately **3.14159** (accurate to 5 decimal places), which matches the mathematical constant π.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calcualte pi to the 5th digit.\n\n    Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and then write tests for it.", type='text'),
#    ToolUseBlock(id='toolu_01B8cvodrLYBDBdimsxkgB2Q', input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01B8cvodrLYBDBdimsxkgB2Q',
#     'content': '"001_tools.ipynb\\n003_tool_streaming.ipynb\\n.backups\\nmain.py\\n005_text_editor_tool.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_013o3NrKKULLf26fYed9mT1h', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_013o3NrKKULLf26fYed9mT1h',
#     'content': '"1: def greeting():\\n2:     print(\\"hi there\\")\\n3: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (also known as the Gregory-Leibniz series) which is a simple and elegant method:", type='text'),
#    ToolUseBlock(id='toolu_01QhrHKxgjXU72Bx76Su4rKs', input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("hi there")', 'new_str': 'def greeting():\n    print("hi there")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate pi to the specified number of decimal digits.\n    Uses the Machin formula for faster convergence.\n    \n    Args:\n        digits: Number of decimal digits to calculate (default: 5)\n    \n    Returns:\n        float: Approximation of pi\n    """\n    # Using Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    # This converges much faster than the Leibniz formula\n    \n    def arctan(x, num_terms):\n        """Calculate arctan using Taylor series"""\n        result = 0\n        x_squared = x * x\n        x_power = x\n        for n in range(num_terms):\n            sign = (-1) ** n\n            result += sign * x_power / (2 * n + 1)\n            x_power *= x_squared\n        return result\n    \n    # Calculate number of terms needed for desired precision\n    # More digits require more terms\n    num_terms = 100 + digits * 20\n    \n    # Machin\'s formula\n    pi_approx = 4 * (4 * arctan(1/5, num_terms) - arctan(1/239, num_terms))\n    \n    return pi_approx'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01QhrHKxgjXU72Bx76Su4rKs',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create a test file to verify our implementation:", type='text'),
#    ToolUseBlock(id='toolu_016TZs6MFnzH9Qj1GXrWyYDk', input={'command': 'create', 'path': './test.py', 'file_text': 'import math\nfrom main import calculate_pi\n\n\ndef test_pi_5_digits():\n    """Test that pi is calculated correctly to 5 decimal places"""\n    calculated_pi = calculate_pi(5)\n    actual_pi = math.pi\n    \n    # Round both to 5 decimal places for comparison\n    calculated_rounded = round(calculated_pi, 5)\n    actual_rounded = round(actual_pi, 5)\n    \n    print(f"Calculated pi: {calculated_pi}")\n    print(f"Actual pi:     {actual_pi}")\n    print(f"Calculated (5 digits): {calculated_rounded}")\n    print(f"Actual (5 digits):     {actual_rounded}")\n    print(f"Difference: {abs(calculated_pi - actual_pi)}")\n    \n    assert calculated_rounded == actual_rounded, \\\n        f"Pi calculation incorrect: got {calculated_rounded}, expected {actual_rounded}"\n    \n    print("✓ Test passed: Pi calculated correctly to 5 decimal places!")\n\n\ndef test_pi_different_precisions():\n    """Test pi calculation with different precision levels"""\n    actual_pi = math.pi\n    \n    print("\\nTesting different precision levels:")\n    for digits in [3, 5, 7, 10]:\n        calculated = calculate_pi(digits)\n        calculated_rounded = round(calculated, digits)\n        actual_rounded = round(actual_pi, digits)\n        \n        match = calculated_rounded == actual_rounded\n        status = "✓" if match else "✗"\n        \n        print(f"{status} {digits} digits: {calculated_rounded} (expected: {actual_rounded})")\n        \n        if digits <= 10:  # Should work for up to 10 digits with our implementation\n            assert match, f"Failed for {digits} digits"\n\n\ndef test_pi_value_range():\n    """Test that calculated pi is in the expected range"""\n    calculated_pi = calculate_pi(5)\n    \n    # Pi should be between 3.14159 and 3.14160\n    assert 3.14159 <= calculated_pi <= 3.14160, \\\n        f"Pi value {calculated_pi} is outside expected range"\n    \n    print("\\n✓ Test passed: Pi is within expected range!")\n\n\nif __name__ == "__main__":\n    print("=" * 60)\n    print("Testing Pi Calculation")\n    print("=" * 60)\n    \n    try:\n        test_pi_5_digits()\n        test_pi_different_precisions()\n        test_pi_value_range()\n        \n        print("\\n" + "=" * 60)\n        print("All tests passed! ✓")\n        print("=" * 60)\n    except AssertionError as e:\n        print(f"\\n✗ Test failed: {e}")\n    except Exception as e:\n        print(f"\\n✗ Unexpected error: {e}")\n'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_016TZs6MFnzH9Qj1GXrWyYDk',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've created both files. Let me show you what was created:", type='text'),
#    ToolUseBlock(id='toolu_014uBDt7WmmeAkWTNMVSDgWH', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_014uBDt7WmmeAkWTNMVSDgWH',
#     'content': '"1: def greeting():\\n2:     print(\\"hi there\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of decimal digits.\\n8:     Uses the Machin formula for faster convergence.\\n9:     \\n10:     Args:\\n11:         digits: Number of decimal digits to calculate (default: 5)\\n12:     \\n13:     Returns:\\n14:         float: Approximation of pi\\n15:     \\"\\"\\"\\n16:     # Using Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n17:     # This converges much faster than the Leibniz formula\\n18:     \\n19:     def arctan(x, num_terms):\\n20:         \\"\\"\\"Calculate arctan using Taylor series\\"\\"\\"\\n21:         result = 0\\n22:         x_squared = x * x\\n23:         x_power = x\\n24:         for n in range(num_terms):\\n25:             sign = (-1) ** n\\n26:             result += sign * x_power / (2 * n + 1)\\n27:             x_power *= x_squared\\n28:         return result\\n29:     \\n30:     # Calculate number of terms needed for desired precision\\n31:     # More digits require more terms\\n32:     num_terms = 100 + digits * 20\\n33:     \\n34:     # Machin\'s formula\\n35:     pi_approx = 4 * (4 * arctan(1/5, num_terms) - arctan(1/239, num_terms))\\n36:     \\n37:     return pi_approx\\n38: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="## Summary\n\nI've successfully created:\n\n### **`./main.py`** - Contains the pi calculation function\n- **`calculate_pi(digits=5)`**: Calculates pi to the specified number of decimal digits (default 5)\n- Uses **Machin's formula**: π/4 = 4·arctan(1/5) - arctan(1/239)\n- This formula converges much faster than simpler methods like the Leibniz series\n- Implements the arctan function using Taylor series expansion\n- Should accurately calculate pi to at least 5 decimal places (3.14159)\n\n### **`./test.py`** - Comprehensive test suite\nContains three test functions:\n1. **`test_pi_5_digits()`**: Verifies pi is calculated correctly to 5 decimal places\n2. **`test_pi_different_precisions()`**: Tests multiple precision levels (3, 5, 7, 10 digits)\n3. **`test_pi_value_range()`**: Ensures the calculated value is within the expected range\n\nYou can run the tests by executing:\n```bash\npython test.py\n```\n\nThe implementation should output pi as approximately **3.14159** (accurate to 5 decimal places), which matches the mathematical constant π.", type='text')]}]
